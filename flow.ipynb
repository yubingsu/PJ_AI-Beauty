# %% [markdown]
# # 0. 개관

# %% [markdown]
# ## 파일 열기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df_japan = pd.read_excel('./oliveyoung_data/oliveyoung_일본_20251221_141513.xlsx')
df_usa = pd.read_excel('./oliveyoung_data/oliveyoung_미국_20251221_045252.xlsx')
df_china = pd.read_excel('./oliveyoung_data/oliveyoung_중국_20251221_174445.xlsx')

# %%
df_japan.head(3)
# Out:
#   country major_category  sub_category  rank  \
# 0   Japan       Skincare  Moisturizers     1
# 1   Japan       Skincare  Moisturizers     1
# 2   Japan       Skincare  Moisturizers     1
#
#                                         product_name brand discount_rate  \
# 0  ★2025 アワード★ Anua PDRNヒアルロン酸カプセル100セラム30ml詰め替え限...   アヌア           53%
# 1  ★2025 アワード★ Anua PDRNヒアルロン酸カプセル100セラム30ml詰め替え限...   アヌア           53%
# 2  ★2025 アワード★ Anua PDRNヒアルロン酸カプセル100セラム30ml詰め替え限...   アヌア           53%
#
#     price  rating                                        ingredients  \
# 0  ¥8,176     4.8  PDRNが配合されて肌調子を健康に整え、艶を与えます。\n11種ヒアルロン酸を配合し、肌の奥...
# 1  ¥8,176     4.8  PDRNが配合されて肌調子を健康に整え、艶を与えます。\n11種ヒアルロン酸を配合し、肌の奥...
# 2  ¥8,176     4.8  PDRNが配合されて肌調子を健康に整え、艶を与えます。\n11種ヒアルロン酸を配合し、肌の奥...
#
#                                          description  \
# 0  一滴も希釈せず、肌の奥から湧き上がるツヤプランピングセラムです。うるおいプランピング効果を与...
# 1  一滴も希釈せず、肌の奥から湧き上がるツヤプランピングセラムです。うるおいプランピング効果を与...
# 2  一滴も希釈せず、肌の奥から湧き上がるツヤプランピングセラムです。うるおいプランピング効果を与...
#
#                                       review_content review_date  \
# 0  これは私の2回目の購入です！本当に素晴らしいです！べたつかず、保湿効果も抜群で、吸収もとても...  2025/12/20
# 1  使用後は、べたつき感がなく、とても快適でしっとりします。塗布後、メイクが非常によく密着します...  2025/12/20
# 2  韓国でこの美容液を購入して自分の肌質にとても合っているので今回はオリーブヤングで直接購入しま...  2025/12/20
#
#    review_rating                              review_detail_ratings  \
# 0              5  {"\u7d20\u65e9\u304f\u6d78\u900f": 5.0, "\u30e...
# 1              5  {"\u7d20\u65e9\u304f\u6d78\u900f": 5.0, "\u30e...
# 2              5  {"\u7d20\u65e9\u304f\u6d78\u900f": 5.0, "\u30e...
#
#                                          product_url
# 0  https://global.oliveyoung.com/product/detail?p...
# 1  https://global.oliveyoung.com/product/detail?p...
# 2  https://global.oliveyoung.com/product/detail?p...

# %% [markdown]
# ## Download

# %%
# !pip install langdetect transformers keybert sentence-transformers scikit-learn
# Out:
# Collecting langdetect
# WARNING: Connection timed out while downloading.
# ERROR: Could not install packages due to an OSError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\Public\\Documents\\ESTsoft\\CreatorTemp\\pip-unpack-mttqbgjk\\transformers-4.57.3-py3-none-any.whl'
# Consider using the `--user` option or check the permissions.
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ------------------- ----------------- 524.3/981.5 kB 91.4 kB/s eta 0:00:06
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ----------------------------- ------- 786.4/981.5 kB 59.1 kB/s eta 0:00:04
#      ------------------------------------- 981.5/981.5 kB 43.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting transformers
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting keybert
#   Downloading keybert-0.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: scikit-learn in c:\users\cub72\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: six in c:\users\cub72\anaconda3\lib\site-packages (from langdetect) (1.17.0)
# Requirement already satisfied: filelock in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\cub72\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\cub72\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: rich>=10.4.0 in c:\users\cub72\anaconda3\lib\site-packages (from keybert) (13.9.4)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: scipy in c:\users\cub72\anaconda3\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cub72\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cub72\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cub72\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cub72\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cub72\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\cub72\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\cub72\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cub72\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (2025.11.12)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    - -------------------------------------- 0.5/12.0 MB 85.1 kB/s eta 0:02:15
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    -- ------------------------------------- 0.8/12.0 MB 74.3 kB/s eta 0:02:31
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    --- ------------------------------------ 1.0/12.0 MB 48.9 kB/s eta 0:03:44
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ---- ----------------------------------- 1.3/12.0 MB 55.8 kB/s eta 0:03:12
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ----- ---------------------------------- 1.6/12.0 MB 64.0 kB/s eta 0:02:43
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34
#    ------ --------------------------------- 1.8/12.0 MB 66.0 kB/s eta 0:02:34

# %%
# !pip install transformers langdetect keybert
# Out:
# Collecting transformers
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting langdetect
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting keybert
#   Using cached keybert-0.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\cub72\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\cub72\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\cub72\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: six in c:\users\cub72\anaconda3\lib\site-packages (from langdetect) (1.17.0)
# Requirement already satisfied: rich>=10.4.0 in c:\users\cub72\anaconda3\lib\site-packages (from keybert) (13.9.4)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\cub72\anaconda3\lib\site-packages (from keybert) (1.6.1)
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Using cached sentence_transformers-5.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cub72\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cub72\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cub72\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cub72\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cub72\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cub72\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (3.5.0)
# Collecting torch>=1.11.0 (from sentence-transformers>=0.3.8->keybert)
#   Using cached torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\cub72\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\cub72\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: colorama in c:\users\cub72\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cub72\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cub72\anaconda3\lib\site-packages (from requests->transformers) (2025.11.12)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.0 MB 645.6 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/12.0 MB 645.6 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/12.0 MB 645.6 kB/s eta 0:00:18
#    -- ------------------------------------- 0.8/12.0 MB 558.4 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/12.0 MB 558.4 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/12.0 MB 533.3 kB/s eta 0:00:21
#    --- ------------------------------------ 1.0/12.0 MB 533.3 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.3/12.0 MB 546.8 kB/s eta 0:00:20
#    ---- ----------------------------------- 1.3/12.0 MB 546.8 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.6/12.0 MB 599.1 kB/s eta 0:00:18
#    ------ --------------------------------- 1.8/12.0 MB 611.4 kB/s eta 0:00:17
#    ------ --------------------------------- 1.8/12.0 MB 611.4 kB/s eta 0:00:17
#    ------ --------------------------------- 2.1/12.0 MB 635.6 kB/s eta 0:00:16
#    ------ --------------------------------- 2.1/12.0 MB 635.6 kB/s eta 0:00:16
#    ------- -------------------------------- 2.4/12.0 MB 639.2 kB/s eta 0:00:16
#    ------- -------------------------------- 2.4/12.0 MB 639.2 kB/s eta 0:00:16
#    -------- ------------------------------- 2.6/12.0 MB 644.6 kB/s eta 0:00:15
#    --------- ------------------------------ 2.9/12.0 MB 649.1 kB/s eta 0:00:15
#    --------- ------------------------------ 2.9/12.0 MB 649.1 kB/s eta 0:00:15
#    ---------- ----------------------------- 3.1/12.0 MB 667.3 kB/s eta 0:00:14
#    ----------- ---------------------------- 3.4/12.0 MB 680.5 kB/s eta 0:00:13
#    ----------- ---------------------------- 3.4/12.0 MB 680.5 kB/s eta 0:00:13
#    ----------- ---------------------------- 3.4/12.0 MB 680.5 kB/s eta 0:00:13
#    ----------- ---------------------------- 3.4/12.0 MB 680.5 kB/s eta 0:00:13
#    ------------ --------------------------- 3.7/12.0 MB 636.5 kB/s eta 0:00:14
#    ------------ --------------------------- 3.7/12.0 MB 636.5 kB/s eta 0:00:14
#    ------------ --------------------------- 3.7/12.0 MB 636.5 kB/s eta 0:00:14
#    ------------- -------------------------- 3.9/12.0 MB 607.5 kB/s eta 0:00:14
#    ------------- -------------------------- 3.9/12.0 MB 607.5 kB/s eta 0:00:14
#    ------------- -------------------------- 4.2/12.0 MB 613.8 kB/s eta 0:00:13
#    ------------- -------------------------- 4.2/12.0 MB 613.8 kB/s eta 0:00:13
#    ------------- -------------------------- 4.2/12.0 MB 613.8 kB/s eta 0:00:13
#    -------------- ------------------------- 4.5/12.0 MB 584.7 kB/s eta 0:00:13
#    -------------- ------------------------- 4.5/12.0 MB 584.7 kB/s eta 0:00:13
#    --------------- ------------------------ 4.7/12.0 MB 596.6 kB/s eta 0:00:13
#    --------------- ------------------------ 4.7/12.0 MB 596.6 kB/s eta 0:00:13
#    --------------- ------------------------ 4.7/12.0 MB 596.6 kB/s eta 0:00:13
#    --------------- ------------------------ 4.7/12.0 MB 596.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.0 MB 569.6 kB/s eta 0:00:13
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ----------------- ---------------------- 5.2/12.0 MB 477.1 kB/s eta 0:00:15
#    ------------------ --------------------- 5.5/12.0 MB 383.4 kB/s eta 0:00:17
#    ------------------ --------------------- 5.5/12.0 MB 383.4 kB/s eta 0:00:17
#    ------------------ --------------------- 5.5/12.0 MB 383.4 kB/s eta 0:00:17
#    ------------------ --------------------- 5.5/12.0 MB 383.4 kB/s eta 0:00:17
#    ------------------ --------------------- 5.5/12.0 MB 383.4 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    ------------------- -------------------- 5.8/12.0 MB 375.9 kB/s eta 0:00:17
#    -------------------- ------------------- 6.0/12.0 MB 359.3 kB/s eta 0:00:17
#    -------------------- ------------------- 6.0/12.0 MB 359.3 kB/s eta 0:00:17
#    -------------------- ------------------- 6.0/12.0 MB 359.3 kB/s eta 0:00:17
#    -------------------- ------------------- 6.0/12.0 MB 359.3 kB/s eta 0:00:17
#    -------------------- ------------------- 6.0/12.0 MB 359.3 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    -------------------- ------------------- 6.3/12.0 MB 349.8 kB/s eta 0:00:17
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    --------------------- ------------------ 6.6/12.0 MB 295.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ---------------------- ----------------- 6.8/12.0 MB 285.6 kB/s eta 0:00:19
#    ----------------------- ---------------- 7.1/12.0 MB 265.9 kB/s eta 0:00:19
#    ----------------------- ---------------- 7.1/12.0 MB 265.9 kB/s eta 0:00:19
#    ----------------------- ---------------- 7.1/12.0 MB 265.9 kB/s eta 0:00:19
#    ----------------------- ---------------- 7.1/12.0 MB 265.9 kB/s eta 0:00:19
#    ----------------------- ---------------- 7.1/12.0 MB 265.9 kB/s eta 0:00:19
#    ----------------------- ---------------- 7.1/12.0 MB 265.9 kB/s eta 0:00:19
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------ --------------- 7.3/12.0 MB 263.3 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    ------------------------- -------------- 7.6/12.0 MB 258.1 kB/s eta 0:00:18
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    -------------------------- ------------- 7.9/12.0 MB 201.1 kB/s eta 0:00:21
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.1/12.0 MB 101.3 kB/s eta 0:00:39
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    --------------------------- ------------ 8.4/12.0 MB 102.8 kB/s eta 0:00:36
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ---------------------------- ----------- 8.7/12.0 MB 98.7 kB/s eta 0:00:34
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ----------------------------- ---------- 8.9/12.0 MB 84.7 kB/s eta 0:00:37
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------ --------- 9.2/12.0 MB 71.6 kB/s eta 0:00:40
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    ------------------------------- -------- 9.4/12.0 MB 70.6 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    -------------------------------- ------- 9.7/12.0 MB 63.5 kB/s eta 0:00:37
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    --------------------------------- ------ 10.0/12.0 MB 66.3 kB/s eta 0:00:31
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.2/12.0 MB 72.0 kB/s eta 0:00:25
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ---------------------------------- ----- 10.5/12.0 MB 75.6 kB/s eta 0:00:20
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ----------------------------------- ---- 10.7/12.0 MB 71.9 kB/s eta 0:00:18
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------ --- 11.0/12.0 MB 72.1 kB/s eta 0:00:14
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    ------------------------------------- -- 11.3/12.0 MB 78.1 kB/s eta 0:00:10
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    -------------------------------------- - 11.5/12.0 MB 81.7 kB/s eta 0:00:06
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------  11.8/12.0 MB 79.7 kB/s eta 0:00:03
#    ---------------------------------------- 12.0/12.0 MB 81.1 kB/s eta 0:00:00
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/566.1 kB ? eta -:--:--
# ...
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    ---------- ----------------------------- 2/8 [torch]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    --------------- ------------------------ 3/8 [huggingface-hub]
#    -------------------- ------------------- 4/8 [tokenizers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------- -------------- 5/8 [transformers]
#    ------------------------------ --------- 6/8 [sentence-transformers]
#    ------------------------------ --------- 6/8 [sentence-transformers]
#    ----------------------------------- ---- 7/8 [keybert]
#    ---------------------------------------- 8/8 [keybert]
#
# Successfully installed huggingface-hub-0.36.0 keybert-0.9.0 langdetect-1.0.9 safetensors-0.7.0 sentence-transformers-5.2.0 tokenizers-0.22.1 torch-2.9.1 transformers-4.57.3
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
from pprint import pprint
from collections import defaultdict, Counter
import re
from transformers import pipeline
from langdetect import detect
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %% [markdown]
# # 1. TEST
#  ## 언어 번역 (일 -> 영)

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return 'en'

lang_map = {
    "ko": "kor_Hang",
    "ja": "jpn_Jpan",
    "en": "eng_Latn",
    "fr": "fra_Latn",
    "de": "deu_Latn",
    "id": "ind_Latn",
}

# TODO: Google/Azure 같은 외부 번역을 붙일지
def normalize_language_and_translate(text):
    lang_code = detect_language(text)
    src_lang = lang_map.get(lang_code, "eng_Latn")
    translated = translator(text, src_lang=src_lang, tgt_lang="eng_Latn")[0]["translation_text"]
    return {"lang": src_lang, "text_en": translated}

# %%
# 첫 번째 리뷰로 테스트
sample_review = df_japan['review_content'].iloc[0]
print(f"원문: {sample_review}")

result = normalize_language_and_translate(sample_review)
print(f"언어: {result['lang']}")
print(f"번역: {result['text_en']}")
# Out:
# 원문: これは私の2回目の購入です！本当に素晴らしいです！べたつかず、保湿効果も抜群で、吸収もとても早いです。このセットには、リフィル、クリーム、さらにコットンパッドも付いており、価格もとてもリーズナブルです！
# 언어: jpn_Jpan
# 번역: This is my second purchase! It's really great! It's all good, it's very humid, it's very absorbent, and it's very fast. This set comes with a filler, a cream, and a cotton pad, and it's very affordable!

# %%
print(f"원문: {df_japan['product_name'].iloc[0]}")
result = normalize_language_and_translate(df_japan['product_name'].iloc[0])
print(f"번역: {result['text_en']}")

print(f"원문: {df_japan['brand'].iloc[0]}")
result = normalize_language_and_translate(df_japan['brand'].iloc[0])
print(f"번역: {result['text_en']}")

print(f"원문: {df_japan['ingredients'].iloc[0]}")
result = normalize_language_and_translate(df_japan['ingredients'].iloc[0])
print(f"번역: {result['text_en']}")

print(f"원문: {df_japan['description'].iloc[0]}")
result = normalize_language_and_translate(df_japan['description'].iloc[0])
print(f"번역: {result['text_en']}")
# Out:
# 원문: ★2025 アワード★ Anua PDRNヒアルロン酸カプセル100セラム30ml詰め替え限定企画(+詰め替え 30ml+クリーム 30ml+パッド 2枚)
# 번역: ★2025 Award★ Anua PDRN Hyaluronic Acid capsule 100 sellam 30ml packing limited project
# 원문: アヌア
# 번역: You know, Anua.
# 원문: PDRNが配合されて肌調子を健康に整え、艶を与えます。
# 11種ヒアルロン酸を配合し、肌の奥までうるおいをチャージします。
# 低分子コラーゲンを配合し、ハリのある肌にケアします。
# 번역: PDRN combines with it to make the skin fit and healthy, to give you moisture, to combine 11 types of hyaluronic acid, to charge the urine down to the bottom of the skin, to combine low-molecular collagen, to take care of the hairy skin.
# 원문: 一滴も希釈せず、肌の奥から湧き上がるツヤプランピングセラムです。うるおいプランピング効果を与え、肌の奥の保湿を改善します。
# リポソームに比べて浸透力の高いスマートカプセルが肌の成分を破壊することなく肌奥まで素早く到達して有効成分の吸収を助けます。
# 成分の吸収を超え、生成の増加までつながる効果を発揮します。使えば使うほど、よりハリのあるうるつや肌に仕上げます。
# 번역: It does not dilute a single drop, but it flows out of the bottom of the skin. It gives a smooth plumbing effect and improves the moisture in the bottom of the skin. Smart capsules with higher penetration than liposomes can quickly reach the bottom of the skin and help absorb the active ingredients without destroying the ingredients.

# %% [markdown]
# # 2. Pipeline
#
# ### [파이프라인 흐름 요약]
# 1. **데이터 로드** → 엑셀 파일에서 리뷰 데이터 읽기
# 2. **번역** → 다국어 리뷰를 영어로 번역 (langdetect + NLLB)
# 3. **문장 분리** → 리뷰를 문장 단위로 분리
# 4. **감정 분석** → 각 문장에 1~5점 감정 점수 부여
# 5. **키워드 추출** → KeyBERT로 리뷰당 5개 키워드 추출
# 6. **클러스터링** → 비슷한 리뷰끼리 그룹화 (0, 1, 2)
# 7. **결과 출력 및 저장** → 콘솔 출력 + 엑셀 저장
#
# ### [결과 해석]
# - `ID`: 리뷰 번호
# - `cluster`: 비슷한 리뷰 그룹 (같은 번호 = 유사한 내용)
# - `score`: 문장 감정 (1=매우부정, 5=매우긍정)
# - `Review sentiment`: 전체 리뷰 감정 (positive/neutral/negative)
# - `KeyBERT keywords`: 추출된 핵심 키워드

# %% [markdown]
# [참고]
# - 사용 더미 데이터: 리뷰 3건(각 리뷰는 2~3문장), 국가/플랫폼/리뷰 텍스트 포함
#
# - 파이프라인 단계:
#
#   - 언어 감지 및 간단 영문화(더미 매핑) — langdetect 사용, NLLB 모델로(`facebook/nllb-200-distilled-600M`)로 감지된 언어 → 영어(`eng_Latn`) 번역
#
#   - 리뷰 문장 분해(문장 단위 분리)
#
#   - `nlptown/bert-base-multilingual-uncased-sentiment` 모델로 각 문장 감정 점수(1~5) 산출: 점수 기준으로 `negative`, `neutral`, `positive` 라벨 부여
#
#   - 리뷰 단위 감정 판단: 문장 점수 평균과 부정 문장 비율 계산
#
#   - 리뷰 전체 코퍼스에 대해 KeyBERT로 대표 키워드 추출
#
#   - TF-IDF 벡터화 + KMeans로 클러스터링
#
#   - 국가/플랫폼별 집계(긍부정 분포, irritation 키워드 빈도) 및 간단한 이슈 탐지 룰(부정 비율 30% 초과, 또는 자극 키워드 탐지 시 알림)

# %%
# =============================================================================
# 올리브영 리뷰 분석 파이프라인 - 리뷰 키워드 추출 (테스트용 10개)
# =============================================================================

import pandas as pd
import numpy as np
from transformers import pipeline
from langdetect import detect
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import re
from collections import defaultdict, Counter
from pprint import pprint

# -----------------------------------------------------------------------------
# 1. 모델 초기화
# -----------------------------------------------------------------------------

translator = pipeline("translation", model="facebook/nllb-200-distilled-600M")
kw_model = KeyBERT()

lang_map = {
    'ja': 'jpn_Jpan',
    'ko': 'kor_Hang',
    'en': 'eng_Latn',
    'zh-cn': 'zho_Hans',
}
# Out:
# Device set to use cpu

# %%
# -----------------------------------------------------------------------------
# 2. 번역 함수
# -----------------------------------------------------------------------------

def normalize_language_and_translate(text):
    try:
        if pd.isna(text) or str(text).strip() == '':
            return {'lang': 'unknown', 'text_en': ''}

        lang_code = detect(str(text))

        if lang_code == 'en':
            return {'lang': 'eng_Latn', 'text_en': str(text)}

        src_lang = lang_map.get(lang_code, 'jpn_Jpan')
        translated = translator(
            str(text),
            src_lang=src_lang,
            tgt_lang='eng_Latn',
            max_length=512
        )[0]['translation_text']

        return {'lang': src_lang, 'text_en': translated}
    except:
        return {'lang': 'unknown', 'text_en': str(text)}

# -----------------------------------------------------------------------------
# 3. 문장 분리 함수
# -----------------------------------------------------------------------------

def split_sentences(text):
    if not text:
        return []
    sentences = re.split(r'[.!?]+', text)
    return [s.strip() for s in sentences if s.strip()]

# -----------------------------------------------------------------------------
# 4. 문장별 감정 점수 (임의)
# -----------------------------------------------------------------------------
def sentiment_of_sentence(sentence):
    """
    문장의 감정 점수 반환 (1~5)
    1: 매우 부정, 2: 부정, 3: 중립, 4: 긍정, 5: 매우 긍정
    """
    if not sentence or len(sentence.strip()) < 3:
        return 3

    try:
        out = sentiment_pipe(sentence)[0]
        return int(out["label"][0])
    except:
        return 3

# -----------------------------------------------------------------------------
# 5. 리뷰 문장 전체 감정 판단 (임의)
# -----------------------------------------------------------------------------

def sentiment_of_review(sentences):
    """
    리뷰 전체 감정 판단
    """
    if not sentences:
        return "neutral"

    scores = [sentiment_of_sentence(s) for s in sentences]

    avg_score = sum(scores) / len(scores)
    neg_ratio = sum(1 for s in scores if s <= 2) / len(scores)

    if neg_ratio >= 0.3:
        return "negative"

    if avg_score >= 4.0:
        return "positive"
    elif avg_score >= 3.0:
        return "neutral"
    else:
        return "negative"

# -----------------------------------------------------------------------------
# 6. KeyBERT 키워드 추출
# -----------------------------------------------------------------------------

custom_stop_words = "english"
    #+ [ #불용어 설정
    #'very', 'truly', 'really', 'quite', 'so',
    #'just', 'absolutely', 'totally', 'extremely' ]

def extract_keywords_keybert(text, top_n=5):
    if not text or len(text.strip()) < 10:
        return []

    try:
        keywords = kw_model.extract_keywords(
            text,
            keyphrase_ngram_range=(1, 2),  # 1-2개 단어 조합 추출 (예: "second purchase", "absorbs very quickly")
            stop_words=custom_stop_words,   # 불용어 제거 (의미 없는 단어 필터링)
            top_n=top_n,                    # 상위 N개 키워드만 추출
            use_mmr=True,                   # MMR 알고리즘 사용 (다양성 확보, 키워드 중복 제거)
            diversity=0.5                   # 0.5 = 관련성과 다양성의 균형 (0.0-1.0, 높을수록 서로 다른 키워드 추출)
        )
        return [kw[0] for kw in keywords]
    except:
        return []

# -----------------------------------------------------------------------------
# 7. 제품별 리뷰 파이프라인 [최종]
# -----------------------------------------------------------------------------

def run_review_pipeline(df, top_n_reviews=None):
    """
    제품별 리뷰 분석 파이프라인

    Args:
        df: 입력 데이터프레임
        top_n_reviews: 처리할 리뷰 개수 (기본값None: 전체)

    Returns:
        list: 처리된 리뷰 결과
    """

    # None이면 전체, 아니면 지정된 개수
    if top_n_reviews is None:
        df_sample = df.copy()
    else:
        df_sample = df.head(top_n_reviews).copy()

    processed = []
    total_reviews = len(df_sample)

    # [개발/테스트용 - 자동화 시 제거 가능] 처리 시작 메시지
    print("===== PROCESSING REVIEWS =====")
    print(f"총 {total_reviews}개 리뷰 처리 시작\n")
    
    for idx, row in df_sample.iterrows():
        # [개발/테스트용 - 자동화 시 제거 가능] 50개마다 진행 상황 출력
        current = idx + 1
        if current % 50 == 0 or current == total_reviews:
            print(f"진행중: {current}/{total_reviews} 리뷰 처리 완료")

        review_id = f"r{idx+1}"
        country = row.get('country', 'Unknown')
        platform = 'oliveyoung_global'
        review_text = row.get('review_content', '')

        norm = normalize_language_and_translate(review_text)
        sentences = split_sentences(norm['text_en'])

        sentence_records = []
        for s in sentences:
            score = sentiment_of_sentence(s)
            sentence_records.append({'sentence': s, 'score': score})

        review_sentiment = sentiment_of_review(sentences)
        keywords = extract_keywords_keybert(norm['text_en'], top_n=5)

        processed.append({
            'id': review_id,
            'country': country,
            'platform': platform,
            'major_category': row.get('major_category', ''),
            'sub_category': row.get('sub_category', ''),
            'product_name': row.get('product_name', ''),
            'brand': row.get('brand', ''),
            'lang': norm['lang'],
            'text_en': norm['text_en'],
            'sentences': sentence_records,
            'review_sentiment': review_sentiment,
            'kw_keybert': keywords,
            'cluster': 0
        })

    # [개발/테스트용 - 자동화 시 제거 가능] 리뷰 처리 완료 메시지
    print(f"\n리뷰 처리 완료: {total_reviews}개")

    if len(processed) >= 3:
        # [개발/테스트용 - 자동화 시 제거 가능] 클러스터링 시작 메시지
        print("클러스터링 시작...")
        
        corpus = [p['text_en'] for p in processed]
        vectorizer = TfidfVectorizer(max_df=0.9, min_df=1, ngram_range=(1, 2), stop_words='english')
        X = vectorizer.fit_transform(corpus)
        n_clusters = max(1, min(3, len(corpus)))
        km = KMeans(n_clusters=n_clusters, random_state=42)
        km.fit(X)
        labels = km.labels_

        for i, p in enumerate(processed):
            p['cluster'] = int(labels[i])
        
        # [개발/테스트용 - 자동화 시 제거 가능] 클러스터링 완료 메시지
        print("클러스터링 완료")

    return processed

# -----------------------------------------------------------------------------
# 8. 결과 출력 함수
# -----------------------------------------------------------------------------

def print_processed_reviews(processed, show_sample=True, sample_size=20):
    """
    처리된 리뷰 결과 출력
    
    Args:
        processed: 처리된 리뷰 리스트
        show_sample: 샘플 출력 여부
        sample_size: 출력할 샘플 개수
    """
    print('\n===== 분석 결과 요약 =====')
    print(f"총 처리된 리뷰: {len(processed)}개")
    
    # 감정 분포
    sentiments = [p.get('review_sentiment') for p in processed]
    positive = sentiments.count('positive')
    neutral = sentiments.count('neutral')
    negative = sentiments.count('negative')
    
    print(f"긍정: {positive}개, 중립: {neutral}개, 부정: {negative}개")
    
    # 클러스터 분포
    clusters = [p.get('cluster') for p in processed]
    cluster_counts = {i: clusters.count(i) for i in set(clusters)}
    print(f"클러스터 분포: {cluster_counts}")
    
    # 샘플 출력
    if show_sample:
        print(f'\n===== 샘플 리뷰 (처음 {min(sample_size, len(processed))}개) =====')
        for p in processed[:sample_size]:
            print(f"\nID: {p['id']} | country: {p['country']} | platform: {p['platform']} | lang: {p['lang']} | cluster: {p['cluster']}")
            for s in p['sentences']:
                print(' -', s)
            print(' Review sentiment:', p.get('review_sentiment'))
            print(' KeyBERT keywords:', p.get('kw_keybert'))

# -----------------------------------------------------------------------------
# 9. 결과를 테이블로 저장 - 확인/기획용
# -----------------------------------------------------------------------------

from datetime import datetime

def save_results_to_table(processed, output_file=None, country=None):
    """
    처리된 리뷰 결과를 테이블 형태로 저장

    Args:
        processed: 처리된 리뷰 리스트
        output_file: 출력 파일명 (None이면 자동 생성)
        country: 국가명 (파일명과 메타데이터용)
    """
    
    # 국가명 자동 추출 (processed에서)
    if country is None and len(processed) > 0:
        country = processed[0].get('country', 'Unknown')
    
    # 타임스탬프 생성
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    
    # 파일명 자동 생성
    if output_file is None:
        output_file = f'./oliveyoung_data/review_analysis_results_{country}_{timestamp}.xlsx'
    
    rows = []

    for p in processed:
        sentences_text = ' | '.join([f"{s['sentence']} (score: {s['score']})" for s in p['sentences']])

        result_row = {
            'review_id': p['id'],
            'country': p['country'],
            'platform': p['platform'],
            'major_category': p.get('major_category', ''),
            'sub_category': p.get('sub_category', ''),
            'product_name': p.get('product_name', ''),
            'brand': p.get('brand', ''),
            'language': p['lang'],
            'translated_text': p['text_en'],
            'sentences': sentences_text,
            'review_sentiment': p['review_sentiment'],
            'keywords': ', '.join(p['kw_keybert']),
            'cluster': p['cluster'],
            'analysis_timestamp': timestamp
        }
        rows.append(result_row)

    result_df = pd.DataFrame(rows)
    result_df.to_excel(output_file, index=False)
    
    # 출력 메시지에 국가와 시간 포함
    print(f"\n[{country}] 분석 완료: {timestamp}")
    print(f"결과가 {output_file}에 저장되었습니다")
    print(f"총 {len(processed)}개 리뷰 처리")

    return result_df

# %%
# 최종적으로는 상품별로 뽑는 것을 고려해야하는 것이 아닌지?

# %%
# =============================================================================
# 실행
# =============================================================================

if __name__ == "__main__":
    # 데이터 로드 
    df = pd.read_excel('./oliveyoung_data/oliveyoung_미국_20251221_045252.xlsx')

    # 파이프라인 실행
    processed = run_review_pipeline(df, top_n_reviews=len(df))

    # 결과 출력 [개발/테스트용 - 자동화 시 제거 가능]
    print_processed_reviews(processed)

    # 결과 저장 (자동으로 국가명+타임스탬프 파일명 생성) [개발/테스트용 - 자동화 시 제거 가능]
    result_df = save_results_to_table(processed)
# Out:
# ===== PROCESSING REVIEWS =====
# 총 12025개 리뷰 처리 시작
#
# 진행중: 50/12025 리뷰 처리 완료
# 진행중: 100/12025 리뷰 처리 완료
# 진행중: 150/12025 리뷰 처리 완료
# 진행중: 200/12025 리뷰 처리 완료
# 진행중: 250/12025 리뷰 처리 완료
# 진행중: 300/12025 리뷰 처리 완료
# 진행중: 350/12025 리뷰 처리 완료
# 진행중: 400/12025 리뷰 처리 완료
# 진행중: 450/12025 리뷰 처리 완료
# 진행중: 500/12025 리뷰 처리 완료
# 진행중: 550/12025 리뷰 처리 완료
# 진행중: 600/12025 리뷰 처리 완료
# 진행중: 650/12025 리뷰 처리 완료
# 진행중: 700/12025 리뷰 처리 완료
# 진행중: 750/12025 리뷰 처리 완료
# 진행중: 800/12025 리뷰 처리 완료
# 진행중: 850/12025 리뷰 처리 완료
# 진행중: 900/12025 리뷰 처리 완료
# 진행중: 950/12025 리뷰 처리 완료
# 진행중: 1000/12025 리뷰 처리 완료
# 진행중: 1050/12025 리뷰 처리 완료
# 진행중: 1100/12025 리뷰 처리 완료
# 진행중: 1150/12025 리뷰 처리 완료
# 진행중: 1200/12025 리뷰 처리 완료
# 진행중: 1250/12025 리뷰 처리 완료
# 진행중: 1300/12025 리뷰 처리 완료
# 진행중: 1350/12025 리뷰 처리 완료
# 진행중: 1400/12025 리뷰 처리 완료
# 진행중: 1450/12025 리뷰 처리 완료
# 진행중: 1500/12025 리뷰 처리 완료
# 진행중: 1550/12025 리뷰 처리 완료
# 진행중: 1600/12025 리뷰 처리 완료
# 진행중: 1650/12025 리뷰 처리 완료
# 진행중: 1700/12025 리뷰 처리 완료
# 진행중: 1750/12025 리뷰 처리 완료
# 진행중: 1800/12025 리뷰 처리 완료
# 진행중: 1850/12025 리뷰 처리 완료
# 진행중: 1900/12025 리뷰 처리 완료
# 진행중: 1950/12025 리뷰 처리 완료
# 진행중: 2000/12025 리뷰 처리 완료
# 진행중: 2050/12025 리뷰 처리 완료
# 진행중: 2100/12025 리뷰 처리 완료
# 진행중: 2150/12025 리뷰 처리 완료
# 진행중: 2200/12025 리뷰 처리 완료
# 진행중: 2250/12025 리뷰 처리 완료
# 진행중: 2300/12025 리뷰 처리 완료
# 진행중: 2350/12025 리뷰 처리 완료
# 진행중: 2400/12025 리뷰 처리 완료
# 진행중: 2450/12025 리뷰 처리 완료
# 진행중: 2500/12025 리뷰 처리 완료
# 진행중: 2550/12025 리뷰 처리 완료
# 진행중: 2600/12025 리뷰 처리 완료
# 진행중: 2650/12025 리뷰 처리 완료
# 진행중: 2700/12025 리뷰 처리 완료
# 진행중: 2750/12025 리뷰 처리 완료
# 진행중: 2800/12025 리뷰 처리 완료
# 진행중: 2850/12025 리뷰 처리 완료
# 진행중: 2900/12025 리뷰 처리 완료
# 진행중: 2950/12025 리뷰 처리 완료
# 진행중: 3000/12025 리뷰 처리 완료
# 진행중: 3050/12025 리뷰 처리 완료
# 진행중: 3100/12025 리뷰 처리 완료
# 진행중: 3150/12025 리뷰 처리 완료
# 진행중: 3200/12025 리뷰 처리 완료
# 진행중: 3250/12025 리뷰 처리 완료
# 진행중: 3300/12025 리뷰 처리 완료
# 진행중: 3350/12025 리뷰 처리 완료
# 진행중: 3400/12025 리뷰 처리 완료
# 진행중: 3450/12025 리뷰 처리 완료
# 진행중: 3500/12025 리뷰 처리 완료
# 진행중: 3550/12025 리뷰 처리 완료
# 진행중: 3600/12025 리뷰 처리 완료
# 진행중: 3650/12025 리뷰 처리 완료
# 진행중: 3700/12025 리뷰 처리 완료
# 진행중: 3750/12025 리뷰 처리 완료
# 진행중: 3800/12025 리뷰 처리 완료
# 진행중: 3850/12025 리뷰 처리 완료
# 진행중: 3900/12025 리뷰 처리 완료
# 진행중: 3950/12025 리뷰 처리 완료
# 진행중: 4000/12025 리뷰 처리 완료
# 진행중: 4050/12025 리뷰 처리 완료
# 진행중: 4100/12025 리뷰 처리 완료
# 진행중: 4150/12025 리뷰 처리 완료
# 진행중: 4200/12025 리뷰 처리 완료
# 진행중: 4250/12025 리뷰 처리 완료
# 진행중: 4300/12025 리뷰 처리 완료
# 진행중: 4350/12025 리뷰 처리 완료
# 진행중: 4400/12025 리뷰 처리 완료
# 진행중: 4450/12025 리뷰 처리 완료
# 진행중: 4500/12025 리뷰 처리 완료
# 진행중: 4550/12025 리뷰 처리 완료
# 진행중: 4600/12025 리뷰 처리 완료
# 진행중: 4650/12025 리뷰 처리 완료
# 진행중: 4700/12025 리뷰 처리 완료
# 진행중: 4750/12025 리뷰 처리 완료
# 진행중: 4800/12025 리뷰 처리 완료
# 진행중: 4850/12025 리뷰 처리 완료
# 진행중: 4900/12025 리뷰 처리 완료
# 진행중: 4950/12025 리뷰 처리 완료
# 진행중: 5000/12025 리뷰 처리 완료
# 진행중: 5050/12025 리뷰 처리 완료
# 진행중: 5100/12025 리뷰 처리 완료
# 진행중: 5150/12025 리뷰 처리 완료
# 진행중: 5200/12025 리뷰 처리 완료
# 진행중: 5250/12025 리뷰 처리 완료
# 진행중: 5300/12025 리뷰 처리 완료
# 진행중: 5350/12025 리뷰 처리 완료
# 진행중: 5400/12025 리뷰 처리 완료
# 진행중: 5450/12025 리뷰 처리 완료
# 진행중: 5500/12025 리뷰 처리 완료
# 진행중: 5550/12025 리뷰 처리 완료
# 진행중: 5600/12025 리뷰 처리 완료
# 진행중: 5650/12025 리뷰 처리 완료
# 진행중: 5700/12025 리뷰 처리 완료
# 진행중: 5750/12025 리뷰 처리 완료
# 진행중: 5800/12025 리뷰 처리 완료
# 진행중: 5850/12025 리뷰 처리 완료
# 진행중: 5900/12025 리뷰 처리 완료
# 진행중: 5950/12025 리뷰 처리 완료
# 진행중: 6000/12025 리뷰 처리 완료
# 진행중: 6050/12025 리뷰 처리 완료
# 진행중: 6100/12025 리뷰 처리 완료
# 진행중: 6150/12025 리뷰 처리 완료
# 진행중: 6200/12025 리뷰 처리 완료
# 진행중: 6250/12025 리뷰 처리 완료
# 진행중: 6300/12025 리뷰 처리 완료
# 진행중: 6350/12025 리뷰 처리 완료
# 진행중: 6400/12025 리뷰 처리 완료
# 진행중: 6450/12025 리뷰 처리 완료
# 진행중: 6500/12025 리뷰 처리 완료
# 진행중: 6550/12025 리뷰 처리 완료
# 진행중: 6600/12025 리뷰 처리 완료
# 진행중: 6650/12025 리뷰 처리 완료
# 진행중: 6700/12025 리뷰 처리 완료
# 진행중: 6750/12025 리뷰 처리 완료
# 진행중: 6800/12025 리뷰 처리 완료
# 진행중: 6850/12025 리뷰 처리 완료
# 진행중: 6900/12025 리뷰 처리 완료
# 진행중: 6950/12025 리뷰 처리 완료
# 진행중: 7000/12025 리뷰 처리 완료
# 진행중: 7050/12025 리뷰 처리 완료
# 진행중: 7100/12025 리뷰 처리 완료
# 진행중: 7150/12025 리뷰 처리 완료
# 진행중: 7200/12025 리뷰 처리 완료
# 진행중: 7250/12025 리뷰 처리 완료
# 진행중: 7300/12025 리뷰 처리 완료
# 진행중: 7350/12025 리뷰 처리 완료
# 진행중: 7400/12025 리뷰 처리 완료
# 진행중: 7450/12025 리뷰 처리 완료
# 진행중: 7500/12025 리뷰 처리 완료
# 진행중: 7550/12025 리뷰 처리 완료
# 진행중: 7600/12025 리뷰 처리 완료
# 진행중: 7650/12025 리뷰 처리 완료
# 진행중: 7700/12025 리뷰 처리 완료
# 진행중: 7750/12025 리뷰 처리 완료
# 진행중: 7800/12025 리뷰 처리 완료
# 진행중: 7850/12025 리뷰 처리 완료
# 진행중: 7900/12025 리뷰 처리 완료
# 진행중: 7950/12025 리뷰 처리 완료
# 진행중: 8000/12025 리뷰 처리 완료
# 진행중: 8050/12025 리뷰 처리 완료
# 진행중: 8100/12025 리뷰 처리 완료
# 진행중: 8150/12025 리뷰 처리 완료
# 진행중: 8200/12025 리뷰 처리 완료
# 진행중: 8250/12025 리뷰 처리 완료
# 진행중: 8300/12025 리뷰 처리 완료
# 진행중: 8350/12025 리뷰 처리 완료
# 진행중: 8400/12025 리뷰 처리 완료
# 진행중: 8450/12025 리뷰 처리 완료
# 진행중: 8500/12025 리뷰 처리 완료
# 진행중: 8550/12025 리뷰 처리 완료
# 진행중: 8600/12025 리뷰 처리 완료
# 진행중: 8650/12025 리뷰 처리 완료
# 진행중: 8700/12025 리뷰 처리 완료
# 진행중: 8750/12025 리뷰 처리 완료
# 진행중: 8800/12025 리뷰 처리 완료
# 진행중: 8850/12025 리뷰 처리 완료
# 진행중: 8900/12025 리뷰 처리 완료
# 진행중: 8950/12025 리뷰 처리 완료
# 진행중: 9000/12025 리뷰 처리 완료
# 진행중: 9050/12025 리뷰 처리 완료
# 진행중: 9100/12025 리뷰 처리 완료
# 진행중: 9150/12025 리뷰 처리 완료
# 진행중: 9200/12025 리뷰 처리 완료
# 진행중: 9250/12025 리뷰 처리 완료
# 진행중: 9300/12025 리뷰 처리 완료
# 진행중: 9350/12025 리뷰 처리 완료
# 진행중: 9400/12025 리뷰 처리 완료
# 진행중: 9450/12025 리뷰 처리 완료
# 진행중: 9500/12025 리뷰 처리 완료
# 진행중: 9550/12025 리뷰 처리 완료
# 진행중: 9600/12025 리뷰 처리 완료
# 진행중: 9650/12025 리뷰 처리 완료
# 진행중: 9700/12025 리뷰 처리 완료
# 진행중: 9750/12025 리뷰 처리 완료
# 진행중: 9800/12025 리뷰 처리 완료
# 진행중: 9850/12025 리뷰 처리 완료
# 진행중: 9900/12025 리뷰 처리 완료
# 진행중: 9950/12025 리뷰 처리 완료
# 진행중: 10000/12025 리뷰 처리 완료
# 진행중: 10050/12025 리뷰 처리 완료
# 진행중: 10100/12025 리뷰 처리 완료
# 진행중: 10150/12025 리뷰 처리 완료
# 진행중: 10200/12025 리뷰 처리 완료
# 진행중: 10250/12025 리뷰 처리 완료
# 진행중: 10300/12025 리뷰 처리 완료
# 진행중: 10350/12025 리뷰 처리 완료
# 진행중: 10400/12025 리뷰 처리 완료
# 진행중: 10450/12025 리뷰 처리 완료
# 진행중: 10500/12025 리뷰 처리 완료
# 진행중: 10550/12025 리뷰 처리 완료
# 진행중: 10600/12025 리뷰 처리 완료
# 진행중: 10650/12025 리뷰 처리 완료
# 진행중: 10700/12025 리뷰 처리 완료
# 진행중: 10750/12025 리뷰 처리 완료
# 진행중: 10800/12025 리뷰 처리 완료
# 진행중: 10850/12025 리뷰 처리 완료
# 진행중: 10900/12025 리뷰 처리 완료
# 진행중: 10950/12025 리뷰 처리 완료
# 진행중: 11000/12025 리뷰 처리 완료
# 진행중: 11050/12025 리뷰 처리 완료
# 진행중: 11100/12025 리뷰 처리 완료
# 진행중: 11150/12025 리뷰 처리 완료
# 진행중: 11200/12025 리뷰 처리 완료
# 진행중: 11250/12025 리뷰 처리 완료
# 진행중: 11300/12025 리뷰 처리 완료
# 진행중: 11350/12025 리뷰 처리 완료
# 진행중: 11400/12025 리뷰 처리 완료
# 진행중: 11450/12025 리뷰 처리 완료
# 진행중: 11500/12025 리뷰 처리 완료
# 진행중: 11550/12025 리뷰 처리 완료
# 진행중: 11600/12025 리뷰 처리 완료
# 진행중: 11650/12025 리뷰 처리 완료
# 진행중: 11700/12025 리뷰 처리 완료
# 진행중: 11750/12025 리뷰 처리 완료
# 진행중: 11800/12025 리뷰 처리 완료
# 진행중: 11850/12025 리뷰 처리 완료
# 진행중: 11900/12025 리뷰 처리 완료
# 진행중: 11950/12025 리뷰 처리 완료
# 진행중: 12000/12025 리뷰 처리 완료
# 진행중: 12025/12025 리뷰 처리 완료
#
# 리뷰 처리 완료: 12025개
# 클러스터링 시작...
# 클러스터링 완료
#
# ===== 분석 결과 요약 =====
# 총 처리된 리뷰: 12025개
# 긍정: 0개, 중립: 12025개, 부정: 0개
# 클러스터 분포: {0: 1999, 1: 7614, 2: 2412}
#
# ===== 샘플 리뷰 (처음 20개) =====
#
# ID: r1 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'This is my second purchase', 'score': 3}
#  - {'sentence': "It's truly amazing", 'score': 3}
#  - {'sentence': "It's not sticky at all, the moisturizing effect is superb, and it absorbs very quickly", 'score': 3}
#  - {'sentence': 'This set also includes a refill, cream, and even a cotton pad, and the price is very reasonable', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['sticky moisturizing', 'amazing sticky', 'absorbs quickly', 'pad price', 'set includes']
#
# ID: r2 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 2
#  - {'sentence': 'It feels very comfortable and moisturizing after use, without any sticky feeling', 'score': 3}
#  - {'sentence': 'Makeup adheres very well after application', 'score': 3}
#  - {'sentence': 'After using it at night, my skin felt very moisturized the next morning, and there were no allergic reactions', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['makeup adheres', 'sticky feeling', 'moisturizing use', 'feels comfortable', 'morning allergic']
#
# ID: r3 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'I bought this serum in Korea and it fits my skin type very well, so I bought it directly from Olive Young this time', 'score': 3}
#  - {'sentence': "It's a genuine product, so it's very safe", 'score': 3}
#  - {'sentence': 'I bought it when it was on sale, but it came with a bottle, refill, and cream, so I was able to buy it cheaply', 'score': 3}
#  - {'sentence': 'I was very happy', 'score': 3}
#  - {'sentence': 'I will repeat it again', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['bought serum', 'skin type', 'product safe', 'directly olive', 'korea fits']
#
# ID: r4 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'The feeling of use is really good', 'score': 3}
#  - {'sentence': "It's not sticky, but it moisturizes, and it goes well with other skincare items", 'score': 3}
#  - {'sentence': "It's really good to use Anua's azelaic acid for the T-zone and chin, and use this one around the cheeks, eyes, and mouth", 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['sticky moisturizes', 'chin use', 'use anua', 'acid zone', 'really good']
#
# ID: r5 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 0
#  - {'sentence': "I've always wanted to use it, so I'm happy to be able to buy it cheaply", 'score': 3}
#  - {'sentence': 'It is moist and easy to use', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['cheaply moist', 'buy cheaply', 'wanted use', 've', 'happy able']
#
# ID: r6 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'This is my second purchase', 'score': 3}
#  - {'sentence': 'really good', 'score': 3}
#  - {'sentence': 'I was surprised that it was better than I expected', 'score': 3}
#  - {'sentence': 'It soaks right into your face', 'score': 3}
#  - {'sentence': 'Last time it came with cream, but this time it comes with a refill, cream, and even a pad at a great price', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['refill cream', 'expected soaks', 'pad great', 'face time', 'purchase really']
#
# ID: r7 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': "I've been using it for a long time, so it's a repeat", 'score': 3}
#  - {'sentence': "It makes you feel full of moisture, so it's essential", 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['moisture essential', 'feel moisture', 'repeat', 'makes feel', 'using long']
#
# ID: r8 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'Some people say topical PDRN isn’t very effective, but it feels nice and moisturising when applied', 'score': 3}
#  - {'sentence': 'It’s definitely better than not using it at all', 'score': 3}
#  - {'sentence': 'For this set and price, it’s cheaper than buying on Amazon, so I’m planning to repurchase', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['topical pdrn', 'moisturising applied', 'say topical', 'isn effective', 'set price']
#
# ID: r9 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 2
#  - {'sentence': "Even though it's very moisturized, it's nice that it's not sticky", 'score': 3}
#  - {'sentence': "It's an inner dry for oily skin, and it fits", 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['dry oily', 'moisturized', 'nice sticky', 'sticky inner', 'skin fits']
#
# ID: r10 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'This is my second repeat', 'score': 3}
#  - {'sentence': 'It was cheaper than buying it on Qoo10, and I only wanted the serum, so it was a great purchase', 'score': 3}
#  - {'sentence': 'It stabilizes skin safety', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['buying qoo10', 'serum', 'stabilizes skin', 'second repeat', 'great']
#
# ID: r11 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': '1st time I’m using PDRN full set, OMG the result is amazing 🤩', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['pdrn set', 'set omg', 'result amazing', 'omg', '1st time']
#
# ID: r12 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 2
#  - {'sentence': 'delivers deep hydration and improved skin resilience with its potent blend of PDRN and hyaluronic acid, leaving skin plump and refreshed', 'score': 3}
#  - {'sentence': 'The added refill, cream, and pads make this set excellent value for a complete, moisture-boosting routine that enhances texture and radiance', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['pdrn hyaluronic', 'cream pads', 'skin plump', 'hydration improved', 'added refill']
#
# ID: r13 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'Love this serum', 'score': 3}
#  - {'sentence': 'Very hydrating and great base for the rest of my routine', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['serum hydrating', 'serum', 'love serum', 'great base', 'routine']
#
# ID: r14 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'This serum has been repeated for about 5 times', 'score': 3}
#  - {'sentence': 'I always keep it in stock at home', 'score': 3}
#  - {'sentence': "this set is so cheap that I buy it every time it's on sale", 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['serum repeated', 'repeated times', 'set cheap', 'times stock', 'home']
#
# ID: r15 | country: USA | platform: oliveyoung_global | lang: unknown | cluster: 1
#  - {'sentence': '😘😍😘😍😘😍😘🙂😘🙂😘🙂😘🙂😘🙂😘🙂😘🙂😘🙂😘🙂😘🙂😘🙂😘', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: []
#
# ID: r16 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'I also use a line for toner etc', 'score': 3}
#  - {'sentence': '‼️ Dryness is severe, so I put it on top of each other', 'score': 3}
#  - {'sentence': "Anyway, since I apply plenty of it, it runs out quickly, so I'm happy with the refill 😄", 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['toner dryness', 'line toner', 'happy refill', 'use line', 'apply plenty']
#
# ID: r17 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': "I don't know what number it is anymore", 'score': 3}
#  - {'sentence': 'I use a variety of serums, but this is a must-have item', 'score': 3}
#  - {'sentence': "It also moisturizes, so I think I'll keep using it", 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['serums item', 'number anymore', 'moisturizes', 'use variety', 'don know']
#
# ID: r18 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'I bought it on an overseas site for the first time because it was thick and super cheap, which is unthinkable with 1buy+1 in Japan', 'score': 3}
#  - {'sentence': 'There was also anxiety about what to do if there was trouble during transportation, etc', 'score': 3}
#  - {'sentence': ', but although it took time due to distribution traffic jams within Japan, they were able to properly monitor delivery, and they also responded very quickly to inquiries, and various concerns were dispelled', 'score': 3}
#  - {'sentence': 'Oriyang is a treasure trove of K-pop cosmetics that I love, so I definitely want to use them again', 'score': 3}
#  - {'sentence': 'Thank you for your support', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['oriyang', 'pop cosmetics', '1buy japan', 'overseas site', 'cheap unthinkable']
#
# ID: r19 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'I am very satisfied that I was able to buy it as a bargain set', 'score': 3}
#  - {'sentence': 'I use it in the morning and evening as an introductory serum', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['introductory serum', 'evening introductory', 'bargain set', 'use morning', 'satisfied able']
#
# ID: r20 | country: USA | platform: oliveyoung_global | lang: eng_Latn | cluster: 1
#  - {'sentence': 'Loved the product', 'score': 3}
#  - {'sentence': 'excellent quality and fast delivery', 'score': 3}
#  - {'sentence': 'Will order again', 'score': 3}
#  Review sentiment: neutral
#  KeyBERT keywords: ['loved product', 'excellent quality', 'delivery order', 'quality fast', 'excellent']
#
# [USA] 분석 완료: 20251227_131435
# 결과가 ./oliveyoung_data/review_analysis_results_USA_20251227_131435.xlsx에 저장되었습니다
# 총 12025개 리뷰 처리

# %% [markdown]
# # 필요한 것
#
# - 현재 KeyBert로 키워드 추출만 한 거라 도움은 되지만 세분화가 필요함. 뷰티 도메인에 맞게 KeyBert로 중요 키워드를 자동으로 뽑고, NER+화장품사전리스트로 성분/제형으로 매칭을 하든지 NER을 뷰티 도메인으로 학습시킬 것
#
# - 키워드 위주로 클러스터링도 해야 함 현재로는 리뷰끼리 비슷한지를 분류하는 느낌
#
# - 번역을 더 자세한 걸로 할지
#
# - 현재 방향성은 이 제품에 대한 이 리뷰가 긍정, 부정, 무난인지(문장이 여러 개면 전체적인 평점인 것) 판단하는 것이므로 이걸로 제품이 긍정적인지~를 알 수 있을 듯
#
# - 시간, 지역, 플랫폼 별 필터링/분석 좀 세분화 필요
#
# - db 아직 연결 안 됨 (구축 후 가져오도록 해야 할 듯?)
#
# - 현재는 제대로 된 리뷰 문장이 있을 경우(이건 올리브영 댓글이 필요할 것 같음. 인스타로는 댓글을 못 보고 캡션에도 필요한 정보가 없긴 함)
#
# - 룰 기반 이나 NER 모델 사용하는데 이걸 키워드 다 적을 수가 있을지
